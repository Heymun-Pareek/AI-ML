# %%
# %pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots() # create a figure with axes using pyplot.subplots() returns fig and axes
plt.subplots(x,y) # FIGURE WITH x-y grid of AXES
ax.plot([1,2,3,4],[1,4,2,3]) # X axis and Y axis # REMEMBER THAT PLOTTING FUNCTIONS ACCEPT ARRAYS np.array so use convertor function np.asarray() when needed
plt.show() # pyplot.show()
print(fig)
# Out:
# Figure(640x480)

# %%
# OO style of creating a plot (I like this one a lot for its clarity)
x = np.linspace(0,2,100) # THIS IS AN ARRAY from 0 -> 2 with 100 spaces in between 
fig, ax = plt.subplots()
ax.plot(x,x,label="linear", linestyle="--") # REMEMBER THAT THE axes plot() function ACCEPTS ARRAYS (ndarray)
ax.plot(x,x**2,label="quadratic")
ax.plot(x,x**3,label="cubic")
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title("Simple Plot")
ax.legend()

# %%
# OO style of creating a plot (I like this one a lot for its clarity)
x = np.linspace(0,2,20) # THIS IS AN ARRAY from 0 -> 2 with 100 spaces in between 
fig, ax = plt.subplots()
ax.plot(x,x,label="linear", linestyle="--") # REMEMBER THAT THE axes plot() function ACCEPTS ARRAYS (ndarray)
ax.plot(x,x**2,label="quadratic",marker="+")
ax.plot(x,x**3,label="cubic")
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title("Simple Plot")
ax.legend()

# %% [markdown]
# #### THIS IS A WAY TO EXPLAIN add_subplot() and how you can use one figure and add many subplots to it

# %%
# generate data
import pandas as pd

cont_data = pd.DataFrame({
    # creates a list of values from -4 to 4 with step 0.1
    'x': np.arange(-4, 4.1, 0.1),
})
# applies quadratic function to x and adds some white noise
cont_data['quadratic'] = cont_data.apply(lambda df: df.x**2 + np.random.normal(0, 1, 1)[0], axis=1)

# applies exponential function to x and adds some white noise
cont_data['exponential'] = cont_data.apply(lambda df: np.e**df.x + np.random.normal(0, 1, 1)[0], axis=1)

cont_data.head()
# Out:
#      x  quadratic  exponential
# 0 -4.0  17.254076    -1.532338
# 1 -3.9  15.395858     0.838220
# 2 -3.8  11.983799    -0.024396
# 3 -3.7  13.967825     0.431624
# 4 -3.6  14.994092    -0.593790

# %%
# Figure can contain multiple plots and you can also set params
fig = plt.figure(figsize=[16, 6])

# Multiple plots on one figure - add_subplot(nrows, ncols, index)
fig.add_subplot(1, 3, 1).plot(cont_data['x'], cont_data['quadratic'], 'k+')
fig.add_subplot(1, 3, 2).plot(cont_data['x'], cont_data['quadratic'], 'ro')
fig.add_subplot(1, 3, 3).plot(cont_data['x'], cont_data['quadratic'], '-g');
